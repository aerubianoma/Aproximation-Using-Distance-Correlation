# %%
from Class import *
from functions import *
seno = toy_model(); 
seno.sen(1000,0.1);
distance_1 = Distance_correlation();
distance_1.x = seno.random_vector_x;
distance_1.y = seno.random_vector_y;
separacion_1 = Distance_correlation();
aproximar_seno = Aproximation(1000,100,10,distance_1,separacion_1,seno);
print("por favor espere")
aproximar_seno.scanner();
# Out:
# por favor espere
# iteracion 0:
# The distance correlation is: 0.9223069247314423
# iteracion 10:
# The distance correlation is: 0.9124699300614376
# iteracion 20:
# The distance correlation is: 0.9127264654837428
# iteracion 30:
# The distance correlation is: 0.9156490217076467
# iteracion 40:
# The distance correlation is: 0.9147311268397441
# iteracion 50:
# The distance correlation is: 0.9203416498367132
# iteracion 60:
# The distance correlation is: 0.9208174238434476
# iteracion 70:
# The distance correlation is: 0.9178086146819469
# iteracion 80:
# The distance correlation is: 0.908898178777487
# iteracion 90:
# The distance correlation is: 0.8972865912329232
# iteracion 100:
# The distance correlation is: 0.8836828669074066
# iteracion 110:
# The distance correlation is: 0.864256856547039
# iteracion 120:
# The distance correlation is: 0.8383503540063918
# iteracion 130:
# The distance correlation is: 0.7845714995460761
# iteracion 140:
# ...

# %%
from Class import *
from functions import *
p_0 = [1,-1]
aproximar_seno.plot();
for i in range(2,6):
    aproximar_seno.number_of_roots = i;
    aproximar_seno.choose_roots();
    aproximar_seno.leastSquares(p_0);
    p_0.append(1);
print(aproximar_seno.norm)
# Out:
# [22.459996334525062, 2.7332785816140164, 2.759230088873371, 2.5053502239844994, 22.459996334525062, 2.7332785816140164, 2.759230088873371, 2.5053502239844994, 22.459996334525062, 2.7332785816140164, 2.759230088873371, 2.5053502239844994, 22.459996334525062, 2.7332785816140164, 2.759230088873371, 2.5053502239844994]

# %%
from Class import *
from functions import *
polinomio_cubico = toy_model(); 
polinomio_cubico.potenciaN(4000,3,0.1);
distance_2 = Distance_correlation();
distance_2.x = polinomio_cubico.random_vector_x;
distance_2.y = polinomio_cubico.random_vector_y;
separacion_2 = Distance_correlation();
aproximar_polinomio_cubico = Aproximation(4000,200,50,distance_2,separacion_2,polinomio_cubico);
print("por favor espere")
aproximar_polinomio_cubico.scanner();
aproximar_polinomio_cubico.number_of_roots = 3;
aproximar_polinomio_cubico.choose_roots();
print(aproximar_polinomio_cubico.critical_points);
# Out:
# por favor espere
# iteracion 0:
# The distance correlation is: 0.7955779653611712
# iteracion 50:
# The distance correlation is: 0.777276915982441
# iteracion 100:
# The distance correlation is: 0.7668644250814021
# iteracion 150:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-62f0ee01c4c4> in <module>()
#       9 aproximar_polinomio_cubico = Aproximation(4000,200,50,distance_2,separacion_2,polinomio_cubico);
#      10 print("por favor espere")
# ---> 11 aproximar_polinomio_cubico.scanner();
#      12 aproximar_polinomio_cubico.number_of_roots = 3;
#      13 aproximar_polinomio_cubico.choose_roots();
#
# C:\Users\usuario\Documents\GitHub\aproximation\distance_correlation\functions.py in scanner(self)
#      23             self.object_distance.x = self.object_toy.random_vector_x[0+i:self.paso+i];
# ...

# %%
from Class import *
def residuos(p, y, x):
    A,B,C,D = p
    error = y-(A*np.exp(-D*(x - 0.20424102838720581)**2)+B*np.exp(-D*(x - -0.14692518385135855)**2)+C*np.exp(-D*(x - -0.003808938799803263)**2))
    return error
p0 = [0, 0, 0, -1/2]
ajuste = leastsq(residuos, p0, args=(distance_2.y, distance_2.x))
print(ajuste[0])
def funcion(x, p):
    return p[0]*np.exp(-p[3]*(x - 0.20424102838720581)**2)+p[1]*np.exp(-p[3]*(x - -0.14692518385135855)**2)+p[2]*np.exp(-p[3]*(x - -0.003808938799803263)**2)
x1 = distance_2.x 
y1 = funcion(distance_2.x, ajuste[0]) 
plt.figure(2)
y2 = x1**3;
plt.plot(distance_2.x,distance_2.y, "o")
plt.plot(x1, y1, 'r-')
plt.plot(x1,y2, "y-")

# %%
from Class import *
from functions import *
polinomio_cuadratico = toy_model(); 
polinomio_cuadratico.potenciaN(1000,2,0.1);
distance_3 = Distance_correlation();
distance_3.x = polinomio_cuadratico.random_vector_x;
distance_3.y = polinomio_cuadratico.random_vector_y;
separacion_3 = Distance_correlation();
aproximar_polinomio_cuadratico = Aproximation(1000,100,10,distance_3,separacion_3,polinomio_cuadratico);
print("por favor espere")
aproximar_polinomio_cuadratico.scanner();
aproximar_polinomio_cuadratico.number_of_roots = 3;
aproximar_polinomio_cuadratico.choose_roots();
print(aproximar_polinomio_cuadratico.critical_points);

# %%
from Class import *
def residuos(p, y, x):
    A,B,C,D = p
    error = y-(A*np.exp(-D*(x - -0.03972172555842657)**2)+B*np.exp(-D*(x - -0.22917826676985098)**2)+C*np.exp(-D*(x - 0.12247662176970175)**2))
    return error
p0 = [0,0,0, -1/2]
ajuste = leastsq(residuos, p0, args=(distance_3.y, distance_3.x))
print(ajuste[0])
def funcion(x, p):
    return p[0]*np.exp(-p[3]*(x - -0.03972172555842657)**2)+p[1]*np.exp(-p[3]*(x - -0.22917826676985098)**2)+p[2]*np.exp(-p[3]*(x - 0.12247662176970175)**2)
x1 = distance_3.x 
y1 = funcion(distance_3.x, ajuste[0]) 
plt.figure(2)
y2 = x1**2;
plt.plot(distance_3.x,distance_3.y, "o")
plt.plot(x1, y1, 'r-')
plt.plot(x1,y2, "y-")

# %%
from Class import *
from functions import *
polinomio_cuadratico = toy_model(); 
polinomio_cuadratico.potenciaN(1000,2,0.1);
distance_3 = Distance_correlation();
distance_3.x = polinomio_cuadratico.random_vector_x;
distance_3.y = polinomio_cuadratico.random_vector_y;
separacion_3 = Distance_correlation();
aproximar_polinomio_cuadratico = Aproximation(1000,100,10,distance_3,separacion_3,polinomio_cuadratico);
print("por favor espere")
aproximar_polinomio_cuadratico.scanner();
aproximar_polinomio_cuadratico.number_of_roots = 1;
aproximar_polinomio_cuadratico.choose_roots();
print(aproximar_polinomio_cuadratico.critical_points);

# %%
from Class import *
def residuos(p, y, x):
    A,D = p
    error = y-A*np.exp(-D*(x - -0.009953159797119415)**2)
    return error
p0 = [0, -1/2]
ajuste = leastsq(residuos, p0, args=(distance_3.y, distance_3.x))
print(ajuste[0])
def funcion(x, p):
    return p[0]*np.exp(-p[1]*(x - -0.009953159797119415)**2)
x1 = distance_3.x 
y1 = funcion(distance_3.x, ajuste[0]) 
plt.figure(2)
y2 = x1**2;
plt.plot(distance_3.x,distance_3.y, "o")
plt.plot(x1, y1, 'r-')
plt.plot(x1,y2, "y-")
