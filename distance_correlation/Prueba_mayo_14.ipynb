# %%
from Class import *
from functions import *
# %matplotlib inline
funcion_1 = toy_model(); 
funcion_1.polinomioUno(4000,0.1);
distance_1 = Distance_correlation();
distance_1.x = funcion_1.random_vector_x;
distance_1.y = funcion_1.random_vector_y;
separacion_1 = Distance_correlation();
aproximar_funcion_1 = Aproximation(4000,200,50,distance_1,separacion_1,funcion_1);
print("por favor espere")
aproximar_funcion_1.scanner();
# Out:
# por favor espere
# iteracion 0:
# The distance correlation is: 0.5193381884740892
# iteracion 50:
# The distance correlation is: 0.40589799308093727
# iteracion 100:
# The distance correlation is: 0.21598976790593302
# iteracion 150:
# The distance correlation is: 0.17708734492280892
# iteracion 200:
# The distance correlation is: 0.11858591580754022
# iteracion 250:
# The distance correlation is: 0.11756383779668231
# iteracion 300:
# The distance correlation is: 0.14260186502001854
# iteracion 350:
# The distance correlation is: 0.16640281415474012
# iteracion 400:
# The distance correlation is: 0.13125632828966205
# iteracion 450:
# The distance correlation is: 0.08827650825296823
# iteracion 500:
# The distance correlation is: 0.12083534967061735
# iteracion 550:
# The distance correlation is: 0.2278136483243866
# iteracion 600:
# The distance correlation is: 0.27841980600386473
# iteracion 650:
# The distance correlation is: 0.2444750959872771
# iteracion 700:
# The distance correlation is: 0.16357953524806657
# iteracion 750:
# The distance correlation is: 0.12694650717687056
# iteracion 800:
# The distance correlation is: 0.14320122450271328
# iteracion 850:
# The distance correlation is: 0.24228097388222833
# iteracion 900:
# The distance correlation is: 0.2613932427292935
# iteracion 950:
# The distance correlation is: 0.19273029156085206
# iteracion 1000:
# The distance correlation is: 0.11767929817335965
# iteracion 1050:
# The distance correlation is: 0.13449528793476903
# iteracion 1100:
# The distance correlation is: 0.15727147443412873
# iteracion 1150:
# The distance correlation is: 0.14467903837230753
# iteracion 1200:
# The distance correlation is: 0.09686743903577746
# iteracion 1250:
# The distance correlation is: 0.08061155789001359
# iteracion 1300:
# The distance correlation is: 0.13950638800075257
# iteracion 1350:
# The distance correlation is: 0.11308380121498893
# iteracion 1400:
# The distance correlation is: 0.13219347180832464
# iteracion 1450:
# The distance correlation is: 0.09955511280187454
# iteracion 1500:
# The distance correlation is: 0.12354899269313628
# iteracion 1550:
# The distance correlation is: 0.09996488966454994
# iteracion 1600:
# The distance correlation is: 0.11066758729900729
# iteracion 1650:
# The distance correlation is: 0.13652940930089139
# iteracion 1700:
# The distance correlation is: 0.1156371581986466
# iteracion 1750:
# The distance correlation is: 0.09701277391265489
# iteracion 1800:
# The distance correlation is: 0.14827565198256082
# iteracion 1850:
# The distance correlation is: 0.11123726153202115
# iteracion 1900:
# The distance correlation is: 0.08955625285448991
# iteracion 1950:
# The distance correlation is: 0.11677300458879339
# iteracion 2000:
# The distance correlation is: 0.17146637450108254
# iteracion 2050:
# The distance correlation is: 0.15776490517529196
# iteracion 2100:
# The distance correlation is: 0.14104704844485305
# iteracion 2150:
# The distance correlation is: 0.1109862510368058
# iteracion 2200:
# The distance correlation is: 0.06774368556347148
# iteracion 2250:
# The distance correlation is: 0.11181690296488887
# iteracion 2300:
# The distance correlation is: 0.0829776632221766
# iteracion 2350:
# The distance correlation is: 0.09366024931189786
# iteracion 2400:
# The distance correlation is: 0.20168917155053417
# iteracion 2450:
# The distance correlation is: 0.10133838681005451
# iteracion 2500:
# The distance correlation is: 0.14636448523180837
# iteracion 2550:
# The distance correlation is: 0.13777401936117736
# iteracion 2600:
# The distance correlation is: 0.09848088529819096
# iteracion 2650:
# The distance correlation is: 0.13029456319600424
# iteracion 2700:
# The distance correlation is: 0.2286362574582901
# iteracion 2750:
# The distance correlation is: 0.15969944230477756
# iteracion 2800:
# The distance correlation is: 0.3133198517788017
# iteracion 2850:
# The distance correlation is: 0.26766994967535496
# iteracion 2900:
# The distance correlation is: 0.20163771758948498
# iteracion 2950:
# The distance correlation is: 0.1938339532997293
# iteracion 3000:
# The distance correlation is: 0.19861135238918917
# iteracion 3050:
# The distance correlation is: 0.24103354267252886
# iteracion 3100:
# The distance correlation is: 0.19127672201747262
# iteracion 3150:
# The distance correlation is: 0.13294289721574773
# iteracion 3200:
# The distance correlation is: 0.11219908562346245
# iteracion 3250:
# The distance correlation is: 0.15192930801493915
# iteracion 3300:
# The distance correlation is: 0.29380594099314633
# iteracion 3350:
# The distance correlation is: 0.30268035505968977
# iteracion 3400:
# The distance correlation is: 0.16780223761292137
# iteracion 3450:
# The distance correlation is: 0.16908858024377746
# iteracion 3500:
# The distance correlation is: 0.18921983337001255
# iteracion 3550:
# The distance correlation is: 0.10875881694865439
# iteracion 3600:
# The distance correlation is: 0.08342139880454139
# iteracion 3650:
# The distance correlation is: 0.09861846616280562
# iteracion 3700:
# The distance correlation is: 0.27223947978782415
# iteracion 3750:
# The distance correlation is: 0.2832473197934444

# %%
from Class import *
from functions import *
# %matplotlib inline
p_0 = [1,1]
aproximar_funcion_1.chooseBestAproximation(p_0,int(4000/200));
# Out:
# C:\Users\usuario\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:427: RuntimeWarning: Number of calls to function has reached maxfev = 2000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# C:\Users\usuario\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:427: RuntimeWarning: Number of calls to function has reached maxfev = 2200.
#   warnings.warn(errors[info][0], RuntimeWarning)
# C:\Users\usuario\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:427: RuntimeWarning: Number of calls to function has reached maxfev = 2400.
#   warnings.warn(errors[info][0], RuntimeWarning)
# C:\Users\usuario\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:427: RuntimeWarning: Number of calls to function has reached maxfev = 2800.
#   warnings.warn(errors[info][0], RuntimeWarning)
# C:\Users\usuario\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:427: RuntimeWarning: Number of calls to function has reached maxfev = 3200.
#   warnings.warn(errors[info][0], RuntimeWarning)
# C:\Users\usuario\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:427: RuntimeWarning: Number of calls to function has reached maxfev = 3800.
#   warnings.warn(errors[info][0], RuntimeWarning)
# 3.68213324083

# %%
print(aproximar_funcion_1.best_aproximation)
# Out:
# 16
